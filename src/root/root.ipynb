# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

from datetime import date

from root.utils import Game, Player, plot_game_stats

# %%
games: list[Game] = [
    Game(
        game_date=date(2025, 5, 2),
        players=[
            Player(name="Agrim", faction="Birds"),
            Player(name="Munira", faction="Woodland"),
            Player(name="Tobi", faction="Duchy"),
            Player(name="Tobias Bl.", faction="Riverfolk", is_winner=True),
        ],
    ),
    Game(
        game_date=date(2025, 5, 7),
        players=[
            Player(name="Agrim", faction="Vagabond"),
            Player(name="Maxi", faction="Cats"),
            Player(name="Munira", faction="Crows", is_winner=True),
            Player(name="Tobi", faction="Duchy"),
            Player(name="Wissal", faction="Woodland"),
        ],
    ),
    Game(
        game_date=date(2025, 5, 13),
        players=[
            Player(name="Alina", faction="Birds"),
            Player(name="Agrim", faction="Vagabond"),
            Player(name="Munira", faction="Woodland", is_winner=True),
            Player(name="Tobi", faction="Duchy"),
        ],
    ),
    Game(
        game_date=date(2025, 5, 20),
        players=[
            Player(name="Agrim", faction="Birds"),
            Player(name="Munira", faction="Duchy"),
            Player(name="Tobi", faction="Woodland", is_winner=True),
        ],
    ),
    Game(
        game_date=date(2025, 6, 10),
        players=[
            Player(name="Agrim", faction="Crows", is_winner=True),
            Player(name="Alina", faction="Birds"),
            Player(name="Georgios", faction="Duchy"),
            Player(name="Tobi", faction="Vagabond"),
        ],
    ),
    Game(
        game_date=date(2025, 8, 25),
        players=[
            Player(name="Ned", faction="Birds", is_winner=True),
            Player(name="Munira", faction="Duchy"),
            Player(name="Tobi", faction="Woodland"),
        ],
    ),
]

# %%
plot_game_stats(games)
